# %%
import numpy as np 
import matplotlib.pyplot as plt


def senal_matriz(edad):
    senal = np.empty((0,))
    matriz = np.empty((0, 100))

    for i in range(edad):
        ventana = np.random.rand() * np.random.randn(100) + np.random.rand()
        senal = np.hstack((senal, ventana))
        matriz = np.vstack((matriz, ventana))

    return senal, matriz

def graficar_senal_y_calcular_estadisticas(senal, matriz):
    medias_desviaciones = []

    plt.figure(figsize=(10, 6))
    plt.plot(senal, label='Señal')
    plt.title('Gráfica de la Señal Generada')
    plt.xlabel('Muestras')
    plt.ylabel('Valor')
    plt.legend()
    plt.grid()
    plt.show()

    for fila in matriz:
        media = np.mean(fila)
        desviacion_estandar = np.std(fila)
        medias_desviaciones.append((media, desviacion_estandar))

    return medias_desviaciones

edad = int(input("Ingresa tu edad (número de iteraciones del ciclo): "))
senal_generada, matriz_ventanas = senal_matriz(edad)
resultados = graficar_senal_y_calcular_estadisticas(senal_generada, matriz_ventanas)

print("Medias y Desviaciones Estándar:")
for i, (media, desviacion) in enumerate(resultados, start=1):
    print(f"Ventana {i}: Media={media:.2f}, Desviación Estándar={desviacion:.2f}")
# Out:
# Medias y Desviaciones Estándar:
# Ventana 1: Media=0.78, Desviación Estándar=0.23
# Ventana 2: Media=0.87, Desviación Estándar=0.86
# Ventana 3: Media=0.76, Desviación Estándar=0.09
# Ventana 4: Media=0.80, Desviación Estándar=0.21
# Ventana 5: Media=0.25, Desviación Estándar=0.87
# Ventana 6: Media=0.99, Desviación Estándar=0.54
# Ventana 7: Media=0.84, Desviación Estándar=0.47
# Ventana 8: Media=0.62, Desviación Estándar=0.81
# Ventana 9: Media=0.13, Desviación Estándar=0.53
# Ventana 10: Media=0.36, Desviación Estándar=0.99
# Ventana 11: Media=1.11, Desviación Estándar=0.91
# Ventana 12: Media=0.24, Desviación Estándar=1.07
# Ventana 13: Media=0.43, Desviación Estándar=0.43
# Ventana 14: Media=0.31, Desviación Estándar=0.15
# Ventana 15: Media=0.70, Desviación Estándar=0.10
# Ventana 16: Media=0.06, Desviación Estándar=0.31
# Ventana 17: Media=0.27, Desviación Estándar=0.95
# Ventana 18: Media=0.32, Desviación Estándar=0.54
# Ventana 19: Media=0.73, Desviación Estándar=0.49
# Ventana 20: Media=0.34, Desviación Estándar=0.38
# Ventana 21: Media=0.85, Desviación Estándar=0.71
# Ventana 22: Media=0.88, Desviación Estándar=0.80
# Ventana 23: Media=0.20, Desviación Estándar=0.32
# Ventana 24: Media=0.72, Desviación Estándar=0.63
# Ventana 25: Media=0.77, Desviación Estándar=0.53
# Ventana 26: Media=0.63, Desviación Estándar=0.50
# Ventana 27: Media=0.64, Desviación Estándar=0.38
# Ventana 28: Media=0.47, Desviación Estándar=0.31
# Ventana 29: Media=0.33, Desviación Estándar=0.61
# Ventana 30: Media=0.45, Desviación Estándar=0.57
# Ventana 31: Media=0.11, Desviación Estándar=0.31
# Ventana 32: Media=0.92, Desviación Estándar=0.18
# Ventana 33: Media=0.18, Desviación Estándar=0.24
# Ventana 34: Media=0.35, Desviación Estándar=0.52
# Ventana 35: Media=0.65, Desviación Estándar=0.20
# Ventana 36: Media=0.95, Desviación Estándar=0.81
# Ventana 37: Media=0.10, Desviación Estándar=0.73
# Ventana 38: Media=0.49, Desviación Estándar=0.66
# Ventana 39: Media=0.02, Desviación Estándar=0.46
# Ventana 40: Media=0.07, Desviación Estándar=0.48
# Ventana 41: Media=0.07, Desviación Estándar=1.01
# Ventana 42: Media=0.20, Desviación Estándar=0.80
# Ventana 43: Media=0.31, Desviación Estándar=0.78
# Ventana 44: Media=0.73, Desviación Estándar=0.74
# Ventana 45: Media=0.14, Desviación Estándar=0.74
# Ventana 46: Media=0.20, Desviación Estándar=0.27
# Ventana 47: Media=0.64, Desviación Estándar=0.76
# Ventana 48: Media=0.94, Desviación Estándar=0.54
# Ventana 49: Media=0.19, Desviación Estándar=0.74
# Ventana 50: Media=0.78, Desviación Estándar=0.35
# Ventana 51: Media=0.16, Desviación Estándar=1.05
# Ventana 52: Media=0.27, Desviación Estándar=0.22
# Ventana 53: Media=0.15, Desviación Estándar=0.31
# Ventana 54: Media=0.45, Desviación Estándar=0.02
# Ventana 55: Media=0.66, Desviación Estándar=0.10
# Ventana 56: Media=0.37, Desviación Estándar=0.91
# Ventana 57: Media=0.04, Desviación Estándar=0.30
# Ventana 58: Media=0.41, Desviación Estándar=0.90
# Ventana 59: Media=0.35, Desviación Estándar=0.85
# Ventana 60: Media=0.85, Desviación Estándar=0.08
# Ventana 61: Media=0.50, Desviación Estándar=0.83
# Ventana 62: Media=0.75, Desviación Estándar=0.63
# Ventana 63: Media=0.91, Desviación Estándar=0.29
# Ventana 64: Media=0.73, Desviación Estándar=0.77
# Ventana 65: Media=0.75, Desviación Estándar=0.25
# Ventana 66: Media=0.15, Desviación Estándar=0.46
# Ventana 67: Media=0.47, Desviación Estándar=0.53
# Ventana 68: Media=0.72, Desviación Estándar=0.69
# Ventana 69: Media=0.30, Desviación Estándar=0.59
# Ventana 70: Media=0.21, Desviación Estándar=0.31
# Ventana 71: Media=0.03, Desviación Estándar=0.12
# Ventana 72: Media=0.30, Desviación Estándar=0.29
# Ventana 73: Media=0.76, Desviación Estándar=0.58
# Ventana 74: Media=0.78, Desviación Estándar=0.71
# Ventana 75: Media=0.46, Desviación Estándar=0.27
# Ventana 76: Media=0.04, Desviación Estándar=0.80
